# %%
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import pandas as pd
matplotlib.rcParams['font.family'] = 'Malgun Gothic'
matplotlib.rcParams['font.size'] = 10
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
values = [30,25,20,13,10,2] #100
# labels = [1,1,1,1,1,1] #100
labels = ['python','java','javascript','C#','C','ETC']
# explode = [0.1]*6
explode = [0.1]*6
colors = ['#4287f5','#9fe02d','#b456e3','#56e3e1','#e39f56','#dee356']
wedgeprops={'width':0.6,'edgecolor':'w','linewidth':2}

# %%
# plt.pie(values,labels=labels,autopct='%.1f%%',
#         explode=explode,startangle=90,counterclock=False,colors=colors,wedgeprops=wedgeprops)
plt.pie(values,labels=labels,autopct='%.1f%%',
        startangle=90,counterclock=False,colors=colors,wedgeprops=wedgeprops,
        pctdistance=0.7)
plt.legend(loc=(1.0,0.8))
plt.show()
