# %%
import matplotlib.pyplot as plt
x = [1,2,3]
y = [2,4,8]
plt.plot(x,y)

# %%
### employees 정보를 가져와서 , 평균 연봉보다 높은 사원을 출력하시오
import oracledb
import pandas as pd
conn = oracledb.connect(user='ora_user',password='1111',dsn='localhost:1521/xe')
print(conn)
cursor = conn.cursor()

# query ='select emp_name, (select avg(salary) <avg  from employees)from employees'
x ='select employee_id,salary from employees'

df = pd.read_sql_query(x,conn)
x_list = list(df['EMPLOYEE_ID'].head(10))
x_list
y_list = df['SALARY'].head(10)
# Out:
# <oracledb.Connection to ora_user@localhost:1521/xe>
# C:\Users\KOREAVC\AppData\Local\Temp\ipykernel_1864\773586878.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(x,conn)
