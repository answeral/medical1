# %%
import pandas as pd
df = pd.read_excel('../z20_data/score.xlsx',index_col='지원번호')
df
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    강나래  구로고  197   90   85  100  95  85      Python
# 2번    강태원  구로고  184   40   35   50  55  25        Java
# 3번    강호림  구로고  168   80   75   70  80  75  javascript
# 4번    김수찬  구로고  187   40   60   70  75  80         NaN
# 5번    김재욱  구로고  188   15   20   10  35  10         NaN
# 6번    박동현  단지고  202   80  100   95  85  80           C
# 7번    박혜정  단지고  188   55   65   45  40  35      PYTHON
# 8번    승근열  단지고  190  100   85   90  95  95          c#

# %%
# 수정 (데이터가 있어야 가능)
df['학교'] = df['학교']+'등학교'
df
# Out:
#        이름         학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    강나래  구로고등학교등학교  197   90   85  100  95  85      Python
# 2번    강태원  구로고등학교등학교  184   40   35   50  55  25        Java
# 3번    강호림  구로고등학교등학교  168   80   75   70  80  75  javascript
# 4번    김수찬  구로고등학교등학교  187   40   60   70  75  80         NaN
# 5번    김재욱  구로고등학교등학교  188   15   20   10  35  10         NaN
# 6번    박동현  단지고등학교등학교  202   80  100   95  85  80           C
# 7번    박혜정  단지고등학교등학교  188   55   65   45  40  35      PYTHON
# 8번    승근열  단지고등학교등학교  190  100   85   90  95  95          c#

# %%
# 수정
df['학교'].replace({'구로고등학교':'디지털고','단지고등학교':'영등포고'},inplace=True)
df
# Out:
#        이름         학교    키   국어   영어   수학  과학  사회        SW특기   결과   합계
# 지원번호
# 1번    강나래  구로고등학교등학교  197   90   85  100  95  85      Python  불합격  455
# 2번    강태원  구로고등학교등학교  184   40   35   50  55  25        Java  불합격  205
# 3번    강호림  구로고등학교등학교  168   80   75   70  80  75  javascript  불합격  380
# 4번    김수찬  구로고등학교등학교  187   40   60   70  75  80         NaN  불합격  325
# 5번    김재욱  구로고등학교등학교  188   15   20   10  35  10         NaN  불합격   90
# 6번    박동현  단지고등학교등학교  202   80  100   95  85  80           C  불합격  440
# 7번    박혜정  단지고등학교등학교  188   55   65   45  40  35      PYTHON  불합격  240
# 8번    승근열  단지고등학교등학교  190  100   85   90  95  95          c#  불합격  465

# %%
df.columns
# Out:
# Index(['이름', '학교', '키', '국어', '영어', '수학', '과학', '사회', 'SW특기', '결과', '합계'], dtype='object')

# %%
df['합계'] = df[df.columns[3]]+df[df.columns[4]]+df[df.columns[5]]+df[df.columns[6]]+df[df.columns[7]]
df
# Out:
#        이름         학교    키   국어   영어   수학  과학  사회        SW특기   결과   합계
# 지원번호
# 1번    강나래  구로고등학교등학교  197   90   85  100  95  85      Python  불합격  455
# 2번    강태원  구로고등학교등학교  184   40   35   50  55  25        Java  불합격  205
# 3번    강호림  구로고등학교등학교  168   80   75   70  80  75  javascript  불합격  380
# 4번    김수찬  구로고등학교등학교  187   40   60   70  75  80         NaN  불합격  325
# 5번    김재욱  구로고등학교등학교  188   15   20   10  35  10         NaN  불합격   90
# 6번    박동현  단지고등학교등학교  202   80  100   95  85  80           C  불합격  440
# 7번    박혜정  단지고등학교등학교  188   55   65   45  40  35      PYTHON  불합격  240
# 8번    승근열  단지고등학교등학교  190  100   85   90  95  95          c#  불합격  465

# %%
df['합계'] = df['국어']+df['과학']+df['사회']+df['수학']+df['영어']
df
# Out:
#        이름         학교    키   국어   영어   수학  과학  사회        SW특기   결과   합계
# 지원번호
# 1번    강나래  구로고등학교등학교  197   90   85  100  95  85      Python  불합격  455
# 2번    강태원  구로고등학교등학교  184   40   35   50  55  25        Java  불합격  205
# 3번    강호림  구로고등학교등학교  168   80   75   70  80  75  javascript  불합격  380
# 4번    김수찬  구로고등학교등학교  187   40   60   70  75  80         NaN  불합격  325
# 5번    김재욱  구로고등학교등학교  188   15   20   10  35  10         NaN  불합격   90
# 6번    박동현  단지고등학교등학교  202   80  100   95  85  80           C  불합격  440
# 7번    박혜정  단지고등학교등학교  188   55   65   45  40  35      PYTHON  불합격  240
# 8번    승근열  단지고등학교등학교  190  100   85   90  95  95          c#  불합격  465

# %%
# 추가 후 수정
df['결과'] = '불합격'
df
# Out:
#        이름         학교    키   국어   영어   수학  과학  사회        SW특기   결과   합계
# 지원번호
# 1번    강나래  구로고등학교등학교  197   90   85  100  95  85      Python  불합격  455
# 2번    강태원  구로고등학교등학교  184   40   35   50  55  25        Java  불합격  205
# 3번    강호림  구로고등학교등학교  168   80   75   70  80  75  javascript  불합격  380
# 4번    김수찬  구로고등학교등학교  187   40   60   70  75  80         NaN  불합격  325
# 5번    김재욱  구로고등학교등학교  188   15   20   10  35  10         NaN  불합격   90
# 6번    박동현  단지고등학교등학교  202   80  100   95  85  80           C  불합격  440
# 7번    박혜정  단지고등학교등학교  188   55   65   45  40  35      PYTHON  불합격  240
# 8번    승근열  단지고등학교등학교  190  100   85   90  95  95          c#  불합격  465

# %%
#  컬럼삭제
df.drop(columns=['합계'],inplace=True)
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[21], line 2
#       1 #  컬럼삭제
# ----> 2 df.drop(columns=['합계'],inplace=True)
#       3 df
#
# File c:\Python312\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# File c:\Python312\Lib\site-packages\pandas\core\generic.py:4788, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786 for axis, labels in axes.items():
#    4787     if labels is not None:
# -> 4788         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4790 if inplace:
#    4791     self._update_inplace(obj)
#
# File c:\Python312\Lib\site-packages\pandas\core\generic.py:4830, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4828         new_axis = axis.drop(labels, level=level, errors=errors)
#    4829     else:
# -> 4830         new_axis = axis.drop(labels, errors=errors)
#    4831     indexer = axis.get_indexer(new_axis)
#    4833 # Case for non-unique axis
#    4834 else:
#
# File c:\Python312\Lib\site-packages\pandas\core\indexes\base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: "['합계'] not found in axis"

# %%
#삭제
df.drop(columns=['국어','영어','수학'],inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 2
#       1 #삭제
# ----> 2 df.drop(columns=['국어','영어','수학'],inplace=True)
#
# File c:\Python312\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# File c:\Python312\Lib\site-packages\pandas\core\generic.py:4788, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786 for axis, labels in axes.items():
#    4787     if labels is not None:
# -> 4788         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4790 if inplace:
#    4791     self._update_inplace(obj)
#
# File c:\Python312\Lib\site-packages\pandas\core\generic.py:4830, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4828         new_axis = axis.drop(labels, level=level, errors=errors)
#    4829     else:
# -> 4830         new_axis = axis.drop(labels, errors=errors)
#    4831     indexer = axis.get_indexer(new_axis)
#    4833 # Case for non-unique axis
#    4834 else:
#
# File c:\Python312\Lib\site-packages\pandas\core\indexes\base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: "['국어', '영어', '수학'] not found in axis"

# %%
df
# Out:
#        이름         학교    키  과학  사회        SW특기   결과
# 지원번호
# 1번    강나래  구로고등학교등학교  197  95  85      Python  불합격
# 2번    강태원  구로고등학교등학교  184  55  25        Java  불합격
# 3번    강호림  구로고등학교등학교  168  80  75  javascript  불합격
# 4번    김수찬  구로고등학교등학교  187  75  80         NaN  불합격
# 5번    김재욱  구로고등학교등학교  188  35  10         NaN  불합격
# 6번    박동현  단지고등학교등학교  202  85  80           C  불합격
# 7번    박혜정  단지고등학교등학교  188  40  35      PYTHON  불합격
# 8번    승근열  단지고등학교등학교  190  95  95          c#  불합격

# %%
# columns 삭제 -> 정확한 columns명을 입력
# index 삭제 -> 정확한 index명을 입력해야 삭제


# index 1개 삭제
df.drop(index='1번',inplace=True)
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[30], line 6
#       1 # columns 삭제 -> 정확한 columns명을 입력
#       2 # index 삭제 -> 정확한 index명을 입력해야 삭제
#       3
#       4
#       5 # index 1개 삭제
# ----> 6 df.drop(index='1번',inplace=True)
#       7 df
#
# File c:\Python312\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# File c:\Python312\Lib\site-packages\pandas\core\generic.py:4788, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786 for axis, labels in axes.items():
#    4787     if labels is not None:
# -> 4788         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4790 if inplace:
#    4791     self._update_inplace(obj)
#
# File c:\Python312\Lib\site-packages\pandas\core\generic.py:4830, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4828         new_axis = axis.drop(labels, level=level, errors=errors)
#    4829     else:
# -> 4830         new_axis = axis.drop(labels, errors=errors)
#    4831     indexer = axis.get_indexer(new_axis)
#    4833 # Case for non-unique axis
#    4834 else:
#
# File c:\Python312\Lib\site-packages\pandas\core\indexes\base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: "['1번'] not found in axis"

# %%
df.index
# Out:
# Index(['4번', '6번', '8번'], dtype='object', name='지원번호')

# %%
df.columns
# Out:
# Index(['이름', '학교', '키', '과학', '사회', 'SW특기', '결과'], dtype='object')

# %%
# 국어 점수가 80점 이상
df['국어']>80
df[df['국어']>80].index
df.drop(index=df[df['국어']>80].index,inplace=True)

# %%
df
# Out:
#        이름   학교    키  국어   영어  수학  과학  사회        SW특기
# 지원번호
# 2번    강태원  구로고  184  40   35  50  55  25        Java
# 3번    강호림  구로고  168  80   75  70  80  75  javascript
# 4번    김수찬  구로고  187  40   60  70  75  80         NaN
# 5번    김재욱  구로고  188  15   20  10  35  10         NaN
# 6번    박동현  단지고  202  80  100  95  85  80           C
# 7번    박혜정  단지고  188  55   65  45  40  35      PYTHON

# %%
## 부분 수정
df.loc['5번','국어'] = 95

# %%
df
# Out:
#        이름   학교    키  국어   영어  수학  과학  사회        SW특기
# 지원번호
# 2번    강태원  구로고  184  40   35  50  55  25        Java
# 3번    강호림  구로고  168  80   75  70  80  75  javascript
# 4번    김수찬  구로고  187  40   60  70  75  80         NaN
# 5번    김재욱  구로고  188  95   20  10  35  10         NaN
# 6번    박동현  단지고  202  80  100  95  85  80           C
# 7번    박혜정  단지고  188  55   65  45  40  35      PYTHON

# %%
# index 여러 개 삭제
df.drop(index=['3번','5번'],inplace=True)
df
# Out:
#        이름         학교    키  과학  사회    SW특기   결과
# 지원번호
# 2번    강태원  구로고등학교등학교  184  55  25    Java  불합격
# 4번    김수찬  구로고등학교등학교  187  75  80     NaN  불합격
# 6번    박동현  단지고등학교등학교  202  85  80       C  불합격
# 7번    박혜정  단지고등학교등학교  188  40  35  PYTHON  불합격
# 8번    승근열  단지고등학교등학교  190  95  95      c#  불합격

# %%
# 조건에 맞는 사람들만 삭제
filt = df['과학'] < 70
df.drop(index=df[filt].index,inplace=True)
df
# Out:
#        이름         학교    키  과학  사회 SW특기   결과
# 지원번호
# 4번    김수찬  구로고등학교등학교  187  75  80  NaN  불합격
# 6번    박동현  단지고등학교등학교  202  85  80    C  불합격
# 8번    승근열  단지고등학교등학교  190  95  95   c#  불합격
